# %% [markdown]
# # SimMIM + BYOL Pretraining
#
# This notebook continues from the fixed SimMIM encoder into BYOL. Checkpoint loading now fails loudly if encoder weights do not match.

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
DATA_ROOT = '/kaggle/input/breakhis/BreaKHis_v1/BreaKHis_v1/histology_slides/breast'
PROJECT_ROOT

# %% [markdown]
# Run SimMIM first if needed.

# %%
# !python scripts/pretrain_simmim.py --data-root "{DATA_ROOT}" --out checkpoints/best_simmim_resnet18.pth --epochs 100 --batch-size 64

# %% [markdown]
# Run BYOL continuation pretraining.

# %%
# !python scripts/pretrain_byol.py --data-root "{DATA_ROOT}" --simmim-checkpoint checkpoints/best_simmim_resnet18.pth --out checkpoints/best_byol_resnet18.pth --epochs 100 --batch-size 64
