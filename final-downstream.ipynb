# %% [markdown]
# # Downstream Fine-Tuning
#
# This notebook uses patient-level splits and evaluates the best validation macro-F1 checkpoint on the held-out test patients.

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
DATA_ROOT = '/kaggle/input/breakhis/BreaKHis_v1/BreaKHis_v1/histology_slides/breast'
PROJECT_ROOT

# %% [markdown]
# Fine-tune subtype classifier.

# %%
# !python scripts/train_downstream.py --data-root "{DATA_ROOT}" --checkpoint checkpoints/best_byol_resnet18.pth --task subtype --out checkpoints/best_downstream_subtype.pth --epochs 80 --batch-size 32

# %% [markdown]
# Optional benign-vs-malignant run.

# %%
# !python scripts/train_downstream.py --data-root "{DATA_ROOT}" --checkpoint checkpoints/best_byol_resnet18.pth --task binary --out checkpoints/best_downstream_binary.pth --epochs 80 --batch-size 32
