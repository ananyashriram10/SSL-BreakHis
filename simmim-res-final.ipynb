# %% [markdown]
# # SimMIM Pretraining
#
# This notebook now delegates to the fixed patient-safe SimMIM script. The old version created a mask but encoded the unmasked image, which weakened the SSL objective.

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
DATA_ROOT = '/kaggle/input/breakhis/BreaKHis_v1/BreaKHis_v1/histology_slides/breast'
PROJECT_ROOT

# %% [markdown]
# Run SimMIM pretraining.

# %%
# !python scripts/pretrain_simmim.py --data-root "{DATA_ROOT}" --out checkpoints/best_simmim_resnet18.pth --epochs 100 --batch-size 64
